# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search", 
    "max_uses": 5
}

# %%
messages = []
add_user_message(
    messages,
    """
    What is the date of the next presidantial election in France?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_01GWcnwJf7HZ5DLGSqvSbxd9', container=None, content=[ServerToolUseBlock(id='srvtoolu_019i9rTRk9x2xm4T7waKVYtA', caller=None, input={'query': 'France presidential election date 2027'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(caller=DirectCaller(type='direct'), content=[WebSearchResultBlock(encrypted_content='...', page_age='1 day ago', title='2027 French presidential election - Wikipedia', type='web_search_result', url='https://en.wikipedia.org/wiki/2027_French_presidential_election'), WebSearchResultBlock(encrypted_content='...', page_age='2 days ago', title='Opinion polling for the 2027 French presidential election - Wikipedia', type='web_search_result', url='https://en.wikipedia.org/wiki/Opinion_polling_for_the_2027_French_presidential_election'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='What are the dates of the next elections? | Service Public', type='web_search_result', url='https://www.service-public.gouv.fr/particuliers/vosdroits/F34852/5_0?lang=en'), WebSearchResultBlock(encrypted_content='...', page_age='March 18, 2026', title='2027 French presidential election (The Blessed Lithosphere) | Future | Fandom', type='web_search_result', url='https://future.fandom.com/wiki/2027_French_presidential_election_(The_Blessed_Lithosphere)'), WebSearchResultBlock(encrypted_content='...', page_age='July 10, 2025', title='Next French election - Wikipedia', type='web_search_result', url='https://en.wikipedia.org/wiki/Next_French_election'), WebSearchResultBlock(encrypted_content='...', page_age='February 26, 2026', title='When is Next French Presidential Election - WhenCount?', type='web_search_result', url='https://whencount.com/france-election/'), WebSearchResultBlock(encrypted_content='...', page_age='2 days ago', title='2027 French presidential election: full list of confirmed and expected candidates', type='web_search_result', url='https://www.connexionfrance.com/news/list-who-is-officially-running-in-the-2027-french-presidential-election/796718'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='French Presidential Election, 2027 - PoliGlobe', type='web_search_result', url='https://poliglobe.com/election/1357')], tool_use_id='srvtoolu_019i9rTRk9x2xm4T7waKVYtA', type='web_search_tool_result'), TextBlock(citations=None, text='The next presidential election in France is ', type='text'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text="Emmanuel Macron's second term, which began on 14 May 2022, is scheduled to end on 13 May 2027, meaning that the first round of the presidential electi...", encrypted_index='EpABCioIEBgCIiRiZGQ1ZTM1OS01NzdiLTQ2ODgtYTIyNy0yYmIwYjg4ZmQ0NjISDP+LP8eGSkKxFSZzyRoMlsf3BCsga15I2MQWIjDi7bgl53hx1qsmt0AvmpqlJydBQPFSct0eo+u6Q7TkYaLKLY6oNnU80FxP9PbGVCoqFJ08qs5WaCuxmV3mvWa4dryiV3vWGAQ=', title='2027 French presidential election - Wikipedia', type='web_search_result_location', url='https://en.wikipedia.org/wiki/2027_French_presidential_election')], text='scheduled to be held between April 8 and 23, 2027', type='text'), TextBlock(citations=None, text='. ', type='text'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text='Presidential elections are scheduled to be held in France in April 2027, with a second round two weeks later if no candidate secures a majority vote. ', encrypted_index='Eo8BCioIEBgCIiRiZGQ1ZTM1OS01NzdiLTQ2ODgtYTIyNy0yYmIwYjg4ZmQ0NjISDFqTqKnvziz/DhjasRoMlmBHShVHZFxEtmOFIjAssX2IO0haHulCcZ9xUBewYluBodfw6zk5KnXrEnzqgGRxDuHNlnFzamrS9KRjl6sqE5lvotZ3q7vpPuM7lLxf7ArAJU8YBA==', title='2027 French presidential election - Wikipedia', type='web_search_result_location', url='https://en.wikipedia.org/wiki/2027_French_presidential_election')], text='If no candidate secures a majority vote in the first round, a second round will be held two weeks later', type='text'), TextBlock(citations=None, text='.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_re ...

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search", 
    "max_uses": 5,
    "allowed_domains": ["gouv.fr"],
}
messages = []
add_user_message(
    messages,
    """
    What is the date of the next presidantial election in France?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_0148NXWBsBttLC2HyzTcJdaZ', container=None, content=[ServerToolUseBlock(id='srvtoolu_014ouLxTZV2o285vTdLDZSQg', caller=None, input={'query': 'next French presidential election date'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(caller=DirectCaller(type='direct'), content=[WebSearchResultBlock(encrypted_content='...', page_age=None, title='What are the dates of the next elections? | Service Public', type='web_search_result', url='https://www.service-public.gouv.fr/particuliers/vosdroits/F34852/5_0?lang=en'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Presidential elections | Service Public', type='web_search_result', url='https://www.service-public.gouv.fr/particuliers/vosdroits/F1940?lang=en'), WebSearchResultBlock(encrypted_content='...', page_age='April 26, 2022', title='Electoral Map -Where can I find the address and number of his polling station? | Service Public', type='web_search_result', url='https://www.service-public.gouv.fr/particuliers/actualites/A15620?lang=en'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Infographic: What comes after the presidential election? - Ministry for Europe and Foreign Affairs', type='web_search_result', url='https://www.diplomatie.gouv.fr/en/coming-to-france/france-facts/the-elections-in-france/infographic-what-comes-after-the-presidential-election/'), WebSearchResultBlock(encrypted_content='', page_age=None, title='The Elections in France - Ministry for Europe and Foreign Affairs', type='web_search_result', url='https://www.diplomatie.gouv.fr/en/coming-to-france/france-facts/the-elections-in-france/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Voting of a Frenchman settled abroad | Service Public', type='web_search_result', url='https://www.service-public.gouv.fr/particuliers/vosdroits/F16904?lang=en'), WebSearchResultBlock(encrypted_content='...', page_age=None, title="Réutilisation - Short study of the first round of 2022's french presidential election | data.gouv.fr", type='web_search_result', url='https://www.data.gouv.fr/reuses/short-study-of-the-first-round-of-2022s-french-presidential-election'), WebSearchResultBlock(encrypted_content='...', page_age='June 9, 2024', title='Legislative 2024 -The dates of the parliamentary elections | Service Public', type='web_search_result', url='https://www.service-public.gouv.fr/particuliers/actualites/A17438?lang=en'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Parliamentary elections | Service Public', type='web_search_result', url='https://www.service-public.gouv.fr/particuliers/vosdroits/F1943?lang=en'), WebSearchResultBlock(encrypted_content='...', page_age='January 19, 2026', title='Elections -Municipal elections 2026: the deadline for registering on the lists of electors is approaching | Service Public', type='web_search_result', url='https://www.service-public.gouv.fr/particuliers/actualites/A15421?lang=en')], tool_use_id='srvtoolu_014ouLxTZV2o285vTdLDZSQg', type='web_search_tool_result'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text='It will take place in 2027.\n\n', encrypted_index='Eo8BCioIEBgCIiRiZGQ1ZTM1OS01NzdiLTQ2ODgtYTIyNy0yYmIwYjg4ZmQ0NjISDJgO73Hek2fZLg50cBoMaM0XWFcmVkzf2G0cIjBOnHHlKSDnBEcRnirHp53XTF146XsWK/o778taPP092FCTG9ebIvSEpaaW4jY++TMqE4tGVCFypsvg3HHJtl6AU+ABm9oYBA==', title='What are the dates of the next elections? | Service Public', type='web_search_result_location', url='https://www.service-public.gouv.fr/particuliers/vosdroits/F34852/5_0?lang=en'), CitationsWebSearchResultLocation(cited_text ...
